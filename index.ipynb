# %% [markdown]
# # Exploring and Transforming JSON Schemas

# %% [markdown]
# # Introduction
#
# In this lesson, you'll formalize how to explore a JSON file whose structure and schema is unknown to you. This often happens in practice when you are handed a file or stumble upon one with little documentation.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Use the JSON module to load and parse JSON documents
# * Load and explore unknown JSON schemas
# * Convert JSON to a pandas dataframe

# %% [markdown]
# ## Loading the JSON file
#
# Load the data from the file `disease_data.json`.

# %%
import pandas as pd
import json
f = open('disease_data.json')
data = json.load(f)

# %% [markdown]
# ## Explore the first and second levels of the schema hierarchy

# %%
pd.DataFrame.from_dict(data['meta'])
# Out:
#                                                                        view
# attribution               Centers for Disease Control and Prevention, Na...
# attributionLink                             http://www.cdc.gov/nccdphp/dph/
# averageRating                                                             0
# category                                         Chronic Disease Indicators
# columns                   [{'id': -1, 'name': 'sid', 'dataTypeName': 'me...
# createdAt                                                        1463517008
# description               CDC's Division of Population Health provides c...
# displayType                                                           table
# downloadCount                                                         80068
# flags                         [default, restorable, restorePossibleForType]
# grants                    [{'inherited': False, 'type': 'viewer', 'flags...
# hideFromCatalog                                                       False
# hideFromDataJson                                                      False
# id                                                                g4ie-h725
# indexUpdatedAt                                                   1531158109
# license                                           {'name': 'Public Domain'}
# licenseId                                                     PUBLIC_DOMAIN
# metadata                  {'rdfSubject': '0', 'rdfClass': '', 'custom_fi...
# name                                  U.S. Chronic Disease Indicators (CDI)
# newBackend                                                            False
# numberOfComments                                                          0
# oid                                                                28887577
# owner                     {'id': 'isr2-3jff', 'displayName': 'DPH Public...
# provenance                                                         official
# publicationAppendEnabled                                              False
# publicationDate                                                  1527195619
# publicationGroup                                                   10787757
# publicationStage                                                  published
# query                                                                    {}
# rights                                                               [read]
# rowClass
# rowsUpdatedAt                                                    1527194748
# rowsUpdatedBy                                                     fwb6-kmt3
# tableAuthor               {'id': 'isr2-3jff', 'displayName': 'DPH Public...
# tableId                                                            15222261
# tags                      [cdi, chronic disease indicators, alcohol, art...
# totalTimesRated                                                           0
# viewCount                                                             15880
# viewLastModified                                                 1531157635
# viewType                                                            tabular

# %%
pd.DataFrame.from_dict(data['data'])
# Out:
#            0                                     1       2           3   \
# 0           1  FF49C41F-CE8D-46C4-9164-653B1227CF6F       1  1527194521
# 1           2  F4468C3D-340A-4CD2-84A3-DF554DFF065E       2  1527194521
# 2           3  65609156-A343-4869-B03F-2BA62E96AC19       3  1527194521
# 3           4  0DB09B00-EFEB-4AC0-9467-A7CBD2B57BF3       4  1527194521
# 4           5  D98DA5BA-6FD6-40F5-A9B1-ABD45E44967B       5  1527194521
# ...       ...                                   ...     ...         ...
# 60261  519150  1B28C1DD-B25F-457E-86E4-7D1463BE82C3  519150  1527194644
# 60262  519704  4FF6ADF8-CC4B-4D94-A5B0-7766346A0D3E  519704  1527194644
# 60263  519705  02896705-4A9F-45A2-A84B-923DEA6DC6A2  519705  1527194644
# 60264  519706  4DF2E74C-5043-474B-9739-98B4D8736BDB  519706  1527194644
# 60265  519707  D742712D-EAFE-401B-83BB-AB93F597E907  519707  1527194644
#
#            4           5       6     7     8     9   ...  32   33      34  \
# 0      959778  1527194521  959778  None  2016  2016  ...  59  ALC  ALC2_2
# 1      959778  1527194521  959778  None  2016  2016  ...  01  ALC  ALC2_2
# 2      959778  1527194521  959778  None  2016  2016  ...  02  ALC  ALC2_2
# 3      959778  1527194521  959778  None  2016  2016  ...  04  ALC  ALC2_2
# 4      959778  1527194521  959778  None  2016  2016  ...  05  ALC  ALC2_2
# ...       ...         ...     ...   ...   ...   ...  ...  ..  ...     ...
# 60261  959778  1527194644  959778  None  2016  2016  ...  72  DIS  DIS1_0
# 60262  959778  1527194644  959778  None  2016  2016  ...  72  OVC  OVC3_1
# 60263  959778  1527194644  959778  None  2016  2016  ...  72  OVC  OVC3_1
# 60264  959778  1527194644  959778  None  2016  2016  ...  72  OVC  OVC3_1
# 60265  959778  1527194644  959778  None  2016  2016  ...  72  OVC  OVC3_1
#
#             35       36    37    38    39    40    41
# 0      CRDPREV  OVERALL   OVR  None  None  None  None
# 1      CRDPREV  OVERALL   OVR  None  None  None  None
# 2      CRDPREV  OVERALL   OVR  None  None  None  None
# 3      CRDPREV  OVERALL   OVR  None  None  None  None
# 4      CRDPREV  OVERALL   OVR  None  None  None  None
# ...        ...      ...   ...   ...   ...   ...   ...
# 60261  CRDPREV     RACE   ASN  None  None  None  None
# 60262  CRDPREV     RACE   BLK  None  None  None  None
# 60263  CRDPREV     RACE  AIAN  None  None  None  None
# 60264  CRDPREV     RACE   ASN  None  None  None  None
# 60265  CRDPREV     RACE   WHT  None  None  None  None
#
# [60266 rows x 42 columns]

# %% [markdown]
# ## Convert to a DataFrame
#
# Create a DataFrame from the JSON file. Be sure to retrive the column names for the dataframe. (Search within the 'meta' key of the master dictionary.) The DataFrame should include all 42 columns.

# %%
df = pd.DataFrame(data['data'])
cols = [i['name'] for i in data['meta']['view']['columns']]
df.columns = cols
df.head()
# Out:
#    sid                                    id  position  created_at  \
# 0    1  FF49C41F-CE8D-46C4-9164-653B1227CF6F         1  1527194521
# 1    2  F4468C3D-340A-4CD2-84A3-DF554DFF065E         2  1527194521
# 2    3  65609156-A343-4869-B03F-2BA62E96AC19         3  1527194521
# 3    4  0DB09B00-EFEB-4AC0-9467-A7CBD2B57BF3         4  1527194521
# 4    5  D98DA5BA-6FD6-40F5-A9B1-ABD45E44967B         5  1527194521
#
#   created_meta  updated_at updated_meta  meta YearStart YearEnd  ...  \
# 0       959778  1527194521       959778  None      2016    2016  ...
# 1       959778  1527194521       959778  None      2016    2016  ...
# 2       959778  1527194521       959778  None      2016    2016  ...
# 3       959778  1527194521       959778  None      2016    2016  ...
# 4       959778  1527194521       959778  None      2016    2016  ...
#
#   LocationID TopicID QuestionID DataValueTypeID StratificationCategoryID1  \
# 0         59     ALC     ALC2_2         CRDPREV                   OVERALL
# 1         01     ALC     ALC2_2         CRDPREV                   OVERALL
# 2         02     ALC     ALC2_2         CRDPREV                   OVERALL
# 3         04     ALC     ALC2_2         CRDPREV                   OVERALL
# 4         05     ALC     ALC2_2         CRDPREV                   OVERALL
#
#   StratificationID1 StratificationCategoryID2 StratificationID2  \
# 0               OVR                      None              None
# 1               OVR                      None              None
# 2               OVR                      None              None
# 3               OVR                      None              None
# 4               OVR                      None              None
#
#   StratificationCategoryID3 StratificationID3
# 0                      None              None
# 1                      None              None
# 2                      None              None
# 3                      None              None
# 4                      None              None
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Level-Up
# ## Create a bar graph of states with the highest asthma rates for adults age 18+

# %% [markdown]
# ## Summary
#
# Well done! In this lab you got some extended practice exploring the structure of JSON files, converting json files to pandas DataFrame, and visualizing data!
